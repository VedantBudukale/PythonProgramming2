# %%
#1 
from PIL import Image
import cv2
img = Image.open("/content/download.jpg")
print(type(img))#print type
print(img.format)#print format
print(img.mode)#print mode
im = cv2.imread("/content/download.jpg")
print(im.shape)#print shape
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (129, 229, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)
plt.colorbar()

# %%
import cv2
from google.colab.patches import cv2_imshow
grey_img = cv2.imread("/content/download.jpg",0)
cv2_imshow(grey_img)
# Out:
# <PIL.Image.Image image mode=L size=229x129 at 0x7F034C2A0710>

# %%
color_img2 = cv2.imread("/content/download.jpg", 1)

plt.imshow(cv2.cvtColor(color_img2, cv2.COLOR_BGR2HSV))

# %%
import numpy as np

[rows,cols] = grey_img.shape;
neg_img = np.zeros((rows,cols));
for r in range(0, rows-1):
  for c in range(0, cols-1):
    neg_img[r,c] = 255-grey_img[r,c]; #Calculate negative image
#plt.imshow(neg_img, cmap=plt.cm.gray)
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img)
ax1.set_title('Original image')
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(grey_img, cmap=plt.cm.gray)
ax2.set_title('Gray image')
ax3 = fig.add_subplot(2,2,3)
ax3.imshow(neg_img)
ax3.set_title('Negative image')
# Out:
# Text(0.5, 1.0, 'Negative image')

# %%
#2
import pandas as pd
df = pd.read_excel("/content/Dress Sales (1).xlsx")
df
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
df.head()
# Out:
#      Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  2013-04-09 00:00:00  \
# 0  1006032852       2114       2274                 2491                 2660
# 1  1212192089        151        275                  570                  750
# 2  1190380701          6          7                    7                    7
# 3   966005983       1005       1128                 1326                 1455
# 4   876339541        996       1175                 1304                 1396
#
#    2013-06-09 00:00:00  2013-08-09 00:00:00  2013-10-09 00:00:00  \
# 0                 2727                 2887                 2930
# 1                  813                 1066                 1164
# 2                    8                    8                    9
# 3                 1507                 1621                 1637
# 4                 1432                 1559                 1570
#
#   2013-12-09 00:00:00 14/9/2013  ... 24/9/2013 26/9/2013 28/9/2013 30/9/2013  \
# ...

# %%
df.tail()
# Out:
#       Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 495  713391965          0          0                    0
# 496  722565148          0          0                    0
# 497  532874347          0          0                    0
# 498  655464934          0          0                    0
# 499  919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 495                  560                  554                  544
# 496                  875                  866                  861
# 497                  734                  728                  726
# 498                  254                  259                  261
# 499                  538                  545                  558
#
#      2013-10-09 00:00:00 2013-12-09 00:00:00 14/9/2013  ... 24/9/2013  \
# 495                  537                 525       519  ...       400
# ...

# %%
df.columns
df['Dress_ID']
# Out:
# 0      1006032852
# 1      1212192089
# 2      1190380701
# 3       966005983
# 4       876339541
#           ...
# 495     713391965
# 496     722565148
# 497     532874347
# 498     655464934
# 499     919930954
# Name: Dress_ID, Length: 500, dtype: int64

# %%
df.describe()
# Out:
#            Dress_ID   29/8/2013    31/8/2013  2013-02-09 00:00:00  \
# count  5.000000e+02   500.00000   500.000000           500.000000
# mean   9.055417e+08   189.76600   200.966000           214.162000
# std    1.736190e+08   568.26459   579.802126           591.975613
# min    4.442820e+08     0.00000     0.000000             0.000000
# 25%    7.673164e+08     0.00000     0.000000             0.000000
# 50%    9.083296e+08     1.00000     1.000000             2.000000
# 75%    1.039534e+09   124.25000   145.250000           179.750000
# max    1.253973e+09  7455.00000  7467.000000          7479.000000
#
#        2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# count           500.000000           500.000000           500.000000
# mean            298.672000           303.658000           315.294000
# std             593.140026           595.178184           600.208193
# min               1.000000             1.000000             1.000000
# ...

# %%
df.dtypes
df.dtypes == 'object'
# Out:
# Dress_ID               False
# 29/8/2013              False
# 31/8/2013              False
# 2013-02-09 00:00:00    False
# 2013-04-09 00:00:00    False
# 2013-06-09 00:00:00    False
# 2013-08-09 00:00:00    False
# 2013-10-09 00:00:00    False
# 2013-12-09 00:00:00     True
# 14/9/2013               True
# 16/9/2013               True
# 18/9/2013               True
# 20/9/2013               True
# 22/9/2013               True
# 24/9/2013              False
# 26/9/2013              False
# 28/9/2013              False
# 30/9/2013              False
# 2013-02-10 00:00:00    False
# 2013-04-10 00:00:00    False
# 2013-06-10 00:00:00    False
# 2010-08-10 00:00:00    False
# 2013-10-10 00:00:00    False
# 2013-12-10 00:00:00    False
# dtype: bool

# %%
df.loc[2:100:25]
# Out:
#       Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 2   1190380701          6          7                    7
# 27  1235426503          6          8                   25
# 52  1160536550         19         25                   40
# 77  1078431253          2          3                    4
#
#     2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 2                     7                    8                    8
# 27                   42                   49                   67
# 52                   44                   47                   55
# 77                    4                    4                    4
#
#     2013-10-09 00:00:00 2013-12-09 00:00:00 14/9/2013  ... 24/9/2013  \
# 2                     9                  10        10  ...        11
# 27                   76                 105       114  ...       253
# 52                   56                  59        59  ...        66
# ...

# %%
df.iloc[0:5,4:7]
# Out:
#    2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00
# 0                 2660                 2727                 2887
# 1                  750                  813                 1066
# 2                    7                    8                    8
# 3                 1455                 1507                 1621
# 4                 1396                 1432                 1559

# %%
df.dropna(axis = 0)
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
df.fillna(value=3)
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
df3 = df.groupby('Dress_ID')
df3

# %%
#3
import pandas as pd
data = {'name' : ['Sudh', 'Krish','Nitesh','Tulesco'],'salary': [100, 200, 300, 400],
        'email': ['spatil@mes.ac.in','krish@mes.ac.in','nitesh@mes.ac.in','tilesco@mes.ac.in'],
        'addr': ['wer', 'ert', 'ert', 'weew']}
df1 = pd.DataFrame(data)
print(df1)
# Out:
#       name  salary              email  addr
# 0     Sudh     100   spatil@mes.ac.in   wer
# 1    Krish     200    krish@mes.ac.in   ert
# 2   Nitesh     300   nitesh@mes.ac.in   ert
# 3  Tulesco     400  tilesco@mes.ac.in  weew

# %%
data1 = {'pf_num':[12,23,34,54],
        'incometax': [132,435,452,123],
         'mobile': [1324123,2314123,341,23423],
         'courses':['ds','big data', 'dl','python']}
df2 = pd.DataFrame(data1)
df2
# Out:
#    pf_num  incometax   mobile   courses
# 0      12        132  1324123        ds
# 1      23        435  2314123  big data
# 2      34        452      341        dl
# 3      54        123    23423    python

# %%
pd.concat([df1,df2])
# Out:
#       name  salary              email  addr  pf_num  incometax     mobile  \
# 0     Sudh   100.0   spatil@mes.ac.in   wer     NaN        NaN        NaN
# 1    Krish   200.0    krish@mes.ac.in   ert     NaN        NaN        NaN
# 2   Nitesh   300.0   nitesh@mes.ac.in   ert     NaN        NaN        NaN
# 3  Tulesco   400.0  tilesco@mes.ac.in  weew     NaN        NaN        NaN
# 0      NaN     NaN                NaN   NaN    12.0      132.0  1324123.0
# 1      NaN     NaN                NaN   NaN    23.0      435.0  2314123.0
# 2      NaN     NaN                NaN   NaN    34.0      452.0      341.0
# 3      NaN     NaN                NaN   NaN    54.0      123.0    23423.0
#
#     courses
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 0        ds
# 1  big data
# 2        dl
# 3    python

# %%
#4
data9 = {'emp_id':[101,102,103,104],
        'salary':[12,45,53,45],
        'providentfund':[12312,3432,234,535]}
data10 = {'emp_id': [101,102,104,103],
       'mobile_no':[12321,3423,2432,2412],
       'house_no':[12312,234,2344,123]}
df9 = pd.DataFrame(data9)
df10 = pd.DataFrame(data10)
df4 = pd.merge(df9,df10, on = ['emp_id'])
df4
# Out:
#    emp_id  salary  providentfund  mobile_no  house_no
# 0     101      12          12312      12321     12312
# 1     102      45           3432       3423       234
# 2     103      53            234       2412       123
# 3     104      45            535       2432      2344

# %%
#5
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df01 = sns.load_dataset('iris')
df01
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#scatter
df01.plot.scatter(x='sepal_length',y = 'sepal_width')

# %%
#hexbin
df01.plot.hexbin(x='sepal_width',y='petal_length',gridsize=10,cmap='viridis')

# %%
#histograph
df01.plot(kind='hist', figsize=(10,10))

# %%
#6
import numpy as np
import matplotlib.pyplot as plt
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');

# %%
#7
class Vehicle:
    def __init__(self, name, mileage, capacity):
        self.name = name
        self.mileage = mileage
        self.capacity = capacity

    def fare(self):
        return self.capacity * 50

class Bus(Vehicle):
    
    def fare(self):
        fare_car = self.capacity * 50
        total_fare = fare_car + (0.1 *fare_car)
        return total_fare

School_bus = Bus("School Volvo", 12, 50)
print("Total Bus fare is:", School_bus.fare())
# Out:
# Total Bus fare is: 2750.0

# %%
#8
class Vehicle:
    def __init__(self, max_speed, mileage):
        self.max_speed = max_speed
        self.mileage = mileage

modelX = Vehicle(240, 18)
print(modelX.max_speed, modelX.mileage)
# Out:
# 240 18

# %%
#9
class Vehicle:
    def __init__(self, name, max_speed, mileage):
        self.name = name
        self.max_speed = max_speed
        self.mileage = mileage

    def seating_capacity(self, capacity):
        return f"The seating capacity of a {self.name} is {capacity} passengers"

class Bus(Vehicle):
    
    def seating_capacity(self, capacity=50):
        return super().seating_capacity(capacity=50)
bus = Bus("Mega Bus", 180, 12)
print(bus.seating_capacity())
# Out:
# The seating capacity of a Mega Bus is 50 passengers

# %%
#10
def ascii(st):
  res=[]
  for index, c in enumerate(st):
    if index%2==0:
      res.append(c.upper())
    else:
      res.append(c.lower())
  return''.join(res)
print(ascii("Vedant"))
# Out:
# VeDaNt

# %%
#11
list = ['v','e','d','a','n','t']
a = {}

for letters in list:
  b = letters.upper()
  a.update({letters:b})
print(a)
# Out:
# {'v': 'V', 'e': 'E', 'd': 'D', 'a': 'A', 'n': 'N', 't': 'T'}

# %%
#12


def num(x,y,z,) :
  if x == y and x == z:
    return 3
  elif x==y or x==z:
    return 2
  else:
    return 0
print(num(2,2,2))
# Out:
# 3

# %%
#13
l = [6,9,4,'ved','budukale']
output = [x for x in l if type(x) != str]
print(output)
# Out:
# [6, 9, 4]

# %%
#14
def recur_factorial(n):
   if n == 1:
       return n
   else:
       return n*recur_factorial(n-1)

num = int(input("Enter the number : "))


if num < 0:
   print("Sorry, factorial does not exist for negative numbers")
elif num == 0:
   print("The factorial of 0 is 1")
else:
   print("The factorial of", num, "is", recur_factorial(num))
# Out:
# Enter the number : 5
# The factorial of 5 is 120

# %%
#15
